# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

from joblib import dump, load

# %%
df = pd.read_csv('https://raw.githubusercontent.com/digipodium/Datasets/main/house_pricing.csv')
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        814 non-null    object
#  1   Type        814 non-null    object
#  2   Beds        814 non-null    int64
#  3   Baths       814 non-null    int64
#  4   SquareFeet  814 non-null    int64
#  5   Price       814 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 38.3+ KB
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46

# %%
X = df[['Beds','Baths','SquareFeet']]
y = df['Price']
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=.2, random_state=1)

# %%
print('Random Forest')
model2 = RandomForestRegressor()
model2.fit(xtrain,ytrain)
print("score:", model2.score(xtest,ytest) * 100)
pred = model2.predict(X)
print("mse:",mean_squared_error(y,pred))
print("mae:",mean_absolute_error(y,pred))
# Out:
# Random Forest
# score: 71.84479403656894
# mse: 886771684.4967629
# mae: 15308.941511423434

# %% [markdown]
# grid search

# %%
# we are going to create a dictionary with all the parameter and their value options

# %%
params = {
    'n_estimators' : list(range(100,501,200)),
    'criterion' : ['squared_error','absolute_error','poisson'],
    'max_depth' : list(range(5,51,25)),
}
params
# Out:
# {'n_estimators': [100, 300, 500],
#  'criterion': ['squared_error', 'absolute_error', 'poisson'],
#  'max_depth': [5, 30]}

# %%
grid = GridSearchCV(estimator=RandomForestRegressor(),param_grid=params,cv=3,n_jobs=-1,verbose=2)

# %%
grid.fit(X,y)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [5, 30],
#                          'n_estimators': [100, 300, 500]},
#              verbose=2)

# %%
gf = pd.DataFrame(grid.cv_results_)

# %%
gf.sort_values(by='rank_test_score',inplace=True)
gf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        3.696626      0.060646         0.093399        0.011905
# 8        5.883177      0.085739         0.173124        0.017975
# 6        1.278573      0.083738         0.038693        0.003300
# 1        1.405331      0.031563         0.116416        0.003303
# 0        0.530710      0.016060         0.039696        0.003773
# 2        2.375352      0.012720         0.168453        0.010538
# 11       8.693505      0.072330         0.204813        0.009037
# 10       5.192020      0.046266         0.115749        0.017606
# 9        1.738567      0.039231         0.042364        0.006604
# 3        0.644124      0.027152         0.050369        0.009111
# 5        3.192933      0.050648         0.204145        0.024073
# 4        1.858653      0.032296         0.117750        0.010633
# 16       2.635204      0.010633         0.111746        0.006133
# 17       3.642252      0.246695         0.140767        0.020692
# 15       0.883293      0.017926         0.038696        0.001249
# 12       0.488013      0.036047         0.035024        0.006485
# 14       2.496439      0.066662         0.145770        0.005561
# 13       1.466045      0.015647         0.092727        0.010144
#
#    param_criterion param_max_depth param_n_estimators  \
# 7   absolute_error               5                300
# 8   absolute_error               5                500
# 6   absolute_error               5                100
# 1    squared_error               5                300
# 0    squared_error               5                100
# 2    squared_error               5                500
# 11  absolute_error              30                500
# 10  absolute_error              30                300
# 9   absolute_error              30                100
# 3    squared_error              30                100
# 5    squared_error              30                500
# 4    squared_error              30                300
# 16         poisson              30                300
# 17         poisson              30                500
# 15         poisson              30                100
# 12         poisson               5                100
# 14         poisson               5                500
# 13         poisson               5                300
#
#                                                params  split0_test_score  \
# 7   {'criterion': 'absolute_error', 'max_depth': 5...           0.825199
# 8   {'criterion': 'absolute_error', 'max_depth': 5...           0.824304
# 6   {'criterion': 'absolute_error', 'max_depth': 5...           0.822383
# 1   {'criterion': 'squared_error', 'max_depth': 5,...           0.803843
# 0   {'criterion': 'squared_error', 'max_depth': 5,...           0.798230
# 2   {'criterion': 'squared_error', 'max_depth': 5,...           0.799472
# 11  {'criterion': 'absolute_error', 'max_depth': 3...           0.760777
# 10  {'criterion': 'absolute_error', 'max_depth': 3...           0.763154
# 9   {'criterion': 'absolute_error', 'max_depth': 3...           0.764590
# 3   {'criterion': 'squared_error', 'max_depth': 30...           0.754530
# 5   {'criterion': 'squared_error', 'max_depth': 30...           0.759581
# 4   {'criterion': 'squared_error', 'max_depth': 30...           0.753988
# 16  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.747369
# 17  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.737823
# 15  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.737382
# 12  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.343005
# 14  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.343656
# 13  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.350039
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 7            0.766921           0.614550         0.735556        0.088811
# 8            0.767459           0.614042         0.735268        0.088806
# 6            0.767525           0.613810         0.734573        0.088280
# 1            0.767904           0.609854         0.727200        0.084264
# 0            0.765024           0.617658         0.726970        0.078475
# 2            0.766913           0.613418         0.726601        0.081129
# 11           0.757983           0.575691         0.698150        0.086599
# 10           0.756123           0.574352         0.697876        0.087392
# 9            0.761569           0.567296         0.697819        0.092301
# 3            0.754013           0.581251         0.696598        0.081563
# 5            0.753121           0.576391         0.696364        0.084875
# 4            0.755012           0.578932         0.695977        0.082765
# 16           0.752355           0.564056         0.687926        0.087613
# 17           0.755966           0.564601         0.686130        0.086253
# 15           0.754771           0.558170         0.683441        0.088864
# 12           0.503692           0.156362         0.334353        0.141929
# 14           0.498307           0.159000         0.333655        0.138702
# 13           0.503182           0.146411         0.333211        0.146136
#
#     rank_test_score
# 7                 1
# 8                 2
# 6                 3
# 1                 4
# 0                 5
# 2                 6
# 11                7
# 10                8
# 9                 9
# 3                10
# 5                11
# 4                12
# 16               13
# 17               14
# 15               15
# 12               16
# 14               17
# 13               18

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=5, n_estimators=300)

# %%
from joblib import dump

# %%
dump(grid.best_estimator_,'house_pricing_model_73.pkl')
# Out:
# ['house_pricing_model_73.pkl']
